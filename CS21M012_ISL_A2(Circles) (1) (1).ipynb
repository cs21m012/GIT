# %% [markdown]
# # **GRID SEARCH CV ON Concentric-Circles DATASET WITH SVC CLASSIFIER**

# %%
from sklearn import svm, datasets
import sklearn

sklearn.metrics.SCORERS.keys()

from sklearn.datasets import make_circles
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
X,y = make_circles(n_samples=100,noise=0.05)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
#X = X.reshape((X.shape[0],-1))
X_train = X_train.reshape((X_train.shape[0],-1))
parameters1 = {'kernel':('linear', 'rbf'), 'C':[1, 10,100]}
svc1 = svm.SVC()
clf1 = GridSearchCV(svc1, parameters1,scoring='roc_auc',refit='AUC')
clf1.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10, 100], 'kernel': ('linear', 'rbf')},
#              refit='AUC', scoring='roc_auc')

# %%
clf1.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
clf1.best_score_
# Out:
# 0.9937003968253968

# %%
from sklearn.metrics import accuracy_score

y1 = clf1.predict(X)
accuracy_score(y, y1)
# Out:
# 0.98

# %%
df_svc_circle = pd.DataFrame(clf1.cv_results_)
df_svc_circle[['param_C', 'param_kernel', 'mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1       linear         0.390228
# 1       1          rbf         0.809772
# 2      10       linear         0.444246
# 3      10          rbf         0.993700
# 4     100       linear         0.340129
# 5     100          rbf         0.987401

# %% [markdown]
# # **GRID SEARCH CV ON MNIST DATASET WITH Random Forest CLASSIFIER**

# %%
from sklearn.ensemble import RandomForestClassifier
parameters2= {
    'max_depth': [1,10,None], 
    
    
}
rfc = RandomForestClassifier() 

clf2 = GridSearchCV(rfc, parameters2,scoring='roc_auc',refit="AUC")
clf2.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [1, 10, None]}, refit='AUC',
#              scoring='roc_auc')

# %%
clf2.best_params_
# Out:
# {'max_depth': 10}

# %%
clf2.best_score_
# Out:
# 0.8687996031746031

# %%
from sklearn.metrics import accuracy_score

y_pred = clf2.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.75

# %%
df_rf_circle = pd.DataFrame(clf2.cv_results_)
df_rf_circle[['param_max_depth', 'mean_test_score']]
# Out:
#   param_max_depth  mean_test_score
# 0               1         0.680258
# 1              10         0.868800
# 2            None         0.855853

# %% [markdown]
# # **GRID SEARCH CV ON MNIST DATASET WITH MLP CLASSIFIER**

# %%
from sklearn.neural_network import MLPClassifier
parameters3 = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}
mlp = MLPClassifier(max_iter=100)

clf3 = GridSearchCV(mlp, parameters3,scoring='roc_auc',refit="AUC")
grid_result=clf3.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# ...

# %%
clf3.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'hidden_layer_sizes': (50, 100, 50),
#  'learning_rate': 'constant',
#  'solver': 'adam'}

# %%
clf3.best_score_
# Out:
# 0.9811011904761905

# %%
from sklearn.metrics import accuracy_score

y_pred = clf3.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.85

# %%
df_mlp_circle = pd.DataFrame(clf3.cv_results_)
df_mlp_circle[['param_hidden_layer_sizes', 'param_activation', 'mean_test_score']]
# Out:
#    param_hidden_layer_sizes param_activation  mean_test_score
# 0              (50, 50, 50)             tanh         0.368452
# 1              (50, 50, 50)             tanh         0.655754
# 2              (50, 50, 50)             tanh         0.457192
# 3              (50, 50, 50)             tanh         0.592262
# 4             (50, 100, 50)             tanh         0.431498
# 5             (50, 100, 50)             tanh         0.753224
# 6             (50, 100, 50)             tanh         0.488244
# 7             (50, 100, 50)             tanh         0.728671
# 8                    (100,)             tanh         0.407044
# 9                    (100,)             tanh         0.453472
# 10                   (100,)             tanh         0.438988
# 11                   (100,)             tanh         0.437550
# 12             (50, 50, 50)             tanh         0.422569
# 13             (50, 50, 50)             tanh         0.640179
# ...
